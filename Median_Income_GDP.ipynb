# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt

# import dataset for GDP from https://data.oecd.org/gdp/gross-domestic-product-gdp.htm
gdpData1 = "datasets/GDP_growth.csv"

# read the data with colums - {'Country', 'Metric, 'Subject', 'Measure', 'Frequency', 'Year', 'Value', 'Flag'}
rawGDP_df1 = pd.read_csv(gdpData)

rawGDP_df1.head()
# Out:
#   LOCATION    Country TRANSACT                                    Transaction  \
# 0      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 1      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 2      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 3      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 4      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
#
#   MEASURE      Measure  TIME  Year Unit Code        Unit  PowerCode Code  \
# 0       G  Growth rate  2012  2012        PC  Percentage               0
# 1       G  Growth rate  2013  2013        PC  Percentage               0
# 2       G  Growth rate  2014  2014        PC  Percentage               0
# 3       G  Growth rate  2015  2015        PC  Percentage               0
# 4       G  Growth rate  2016  2016        PC  Percentage               0
#
# ...

# %%
df1 = rawGDP_df1.copy().sort_values(by = 'TIME', ascending = False)
df1.head()
# Out:
#     LOCATION                        Country TRANSACT  \
# 382      ROU                        Romania    B1_GE
# 161     EU15  European Union (15 countries)    B1_GE
# 210      SVN                       Slovenia    B1_GE
# 370      MLT                          Malta    B1_GE
# 203      ITA                          Italy    B1_GE
#
#                                        Transaction MEASURE      Measure  TIME  \
# 382  Gross domestic product (expenditure approach)       G  Growth rate  2018
# 161  Gross domestic product (expenditure approach)       G  Growth rate  2018
# 210  Gross domestic product (expenditure approach)       G  Growth rate  2018
# 370  Gross domestic product (expenditure approach)       G  Growth rate  2018
# 203  Gross domestic product (expenditure approach)       G  Growth rate  2018
#
#      Year Unit Code        Unit  PowerCode Code PowerCode  \
# 382  2018        PC  Percentage               0     Units
# ...

# %%
df1= df1.drop_duplicates(subset=['LOCATION'], keep='first')
df1.head()
# Out:
#     LOCATION                        Country TRANSACT  \
# 382      ROU                        Romania    B1_GE
# 161     EU15  European Union (15 countries)    B1_GE
# 210      SVN                       Slovenia    B1_GE
# 370      MLT                          Malta    B1_GE
# 203      ITA                          Italy    B1_GE
#
#                                        Transaction MEASURE      Measure  TIME  \
# 382  Gross domestic product (expenditure approach)       G  Growth rate  2018
# 161  Gross domestic product (expenditure approach)       G  Growth rate  2018
# 210  Gross domestic product (expenditure approach)       G  Growth rate  2018
# 370  Gross domestic product (expenditure approach)       G  Growth rate  2018
# 203  Gross domestic product (expenditure approach)       G  Growth rate  2018
#
#      Year Unit Code        Unit  PowerCode Code PowerCode  \
# 382  2018        PC  Percentage               0     Units
# ...

# %%
df1 = df1.sort_values(by='Value', ascending=False)
df1[['Country','Value']].plot(kind='bar', x='Country', figsize=(12,6), title='GDP Value (USD/Capita) by Country Code')
plt.show()

# %%
# import dataset for GDP from https://data.oecd.org/gdp/gross-domestic-product-gdp.htm
HDIData1 = "datasets/HDI_growth.csv"

# read the data with colums - {'Country', 'Metric, 'Subject', 'Measure', 'Frequency', 'Year', 'Value', 'Flag'}
rawHDI_df1 = pd.read_csv(HDIData1)

rawHDI_df1.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value Flag Codes
# 0      AUS      HHDI     NET  AGRWTH         A  2016  2.061030        NaN
# 1      AUS      HHDI     NET  AGRWTH         A  2017  2.089534        NaN
# 2      AUS      HHDI     NET  AGRWTH         A  2018  1.981832        NaN
# 3      AUS      HHDI     NET  AGRWTH         A  2019  4.389412        NaN
# 4      AUT      HHDI     NET  AGRWTH         A  2016  2.596186        NaN

# %%
df_HDI1 = rawHDI_df1.copy().sort_values(by = 'TIME', ascending = False)
df_HDI1.head()
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value Flag Codes
# 135      LTU      HHDI     NET  AGRWTH         A  2019  6.752688        NaN
# 118      ZAF      HHDI     NET  AGRWTH         A  2019  1.278558        NaN
# 114      SVN      HHDI     NET  AGRWTH         A  2019  4.086643        NaN
# 80       PRT      HHDI     NET  AGRWTH         A  2019  2.810126          E
# 47       IRL      HHDI     NET  AGRWTH         A  2019  4.973398        NaN

# %%
df_HDI1 = df_HDI1.drop_duplicates(subset=['LOCATION'], keep='first')
df_HDI1 = df_HDI1.drop(columns=[])
df_HDI1.head()
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value Flag Codes
# 135      LTU      HHDI     NET  AGRWTH         A  2019  6.752688        NaN
# 118      ZAF      HHDI     NET  AGRWTH         A  2019  1.278558        NaN
# 114      SVN      HHDI     NET  AGRWTH         A  2019  4.086643        NaN
# 80       PRT      HHDI     NET  AGRWTH         A  2019  2.810126          E
# 47       IRL      HHDI     NET  AGRWTH         A  2019  4.973398        NaN

# %%
df_HDI1 = df_HDI1.sort_values(by='Value', ascending=False)
df_HDI1[['LOCATION','Value']].plot(kind='bar', x='LOCATION', figsize=(12,6), title='Household Disposable Income by Country as a Percentage of Annual Growth')
plt.show()

# %%
codes_df1 = pd.read_html('https://laendercode.net/en/3-letter-list.html')[0]
codes_df1.head()
# Out:
#   ISO 3166 ALPHA-3         Country
# 0              AFG     Afghanistan
# 1              ALA   Aland Islands
# 2              ALB         Albania
# 3              DZA         Algeria
# 4              ASM  American Samoa

# %%
merged_df1 = df_HDI1.merge(codes_df, left_on=['LOCATION'], right_on=['ISO 3166 ALPHA-3'])
merged_df1.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value Flag Codes  \
# 0      CRI      HHDI     NET  AGRWTH         A  2016  7.371562        NaN
# 1      LTU      HHDI     NET  AGRWTH         A  2019  6.752688        NaN
# 2      EST      HHDI     NET  AGRWTH         A  2019  6.491586        NaN
# 3      POL      HHDI     NET  AGRWTH         A  2019  6.189668        NaN
# 4      IRL      HHDI     NET  AGRWTH         A  2019  4.973398        NaN
#
#   ISO 3166 ALPHA-3     Country
# 0              CRI  Costa Rica
# 1              LTU   Lithuania
# 2              EST     Estonia
# 3              POL      Poland
# 4              IRL     Ireland

# %%
merged_df1[['Country','Value']].plot(kind='bar', x='Country', figsize=(12,6), title='Household Disposable Income by Country as a Percentage of Annual Growth')
plt.show()

# %%
df1 = df1.merge(merged_df2, left_on=['Country'], right_on = ['Country']) 
df1
# Out:
#    LOCATION_x         Country TRANSACT  \
# 0         IRL         Ireland    B1_GE
# 1         POL          Poland    B1_GE
# 2         HUN         Hungary    B1_GE
# 3         LVA          Latvia    B1_GE
# 4         SVN        Slovenia    B1_GE
# 5         EST         Estonia    B1_GE
# 6         LTU       Lithuania    B1_GE
# 7         CRI      Costa Rica    B1_GE
# 8         CZE  Czech Republic    B1_GE
# 9         USA   United States    B1_GE
# 10        NZL     New Zealand    B1_GE
# 11        AUT         Austria    B1_GE
# 12        AUS       Australia    B1_GE
# 13        NLD     Netherlands    B1_GE
# 14        LUX      Luxembourg    B1_GE
# 15        ESP           Spain    B1_GE
# 16        CHE     Switzerland    B1_GE
# 17        SWE          Sweden    B1_GE
# 18        FIN         Finland    B1_GE
# 19        PRT        Portugal    B1_GE
# 20        MEX          Mexico    B1_GE
# 21        GRC          Greece    B1_GE
# 22        CAN          Canada    B1_GE
# ...

# %%
# Create a figure for the combined plot
fig,ax = plt.subplots(figsize=(12,6))

# Plot the GDP data on the first axis
ax.plot(df1['Country'], df1['Value_x'], color="darkorange", marker="o")
ax.set_xlabel('Country', fontsize=14)
ax.set_ylabel("GDP (USD/Capita)",color="darkorange",fontsize=14)
ax.set_ylim(ymin=0)

# Create a twin object from the first axis, to allow two different y-axis on the same plot
ax2=ax.twinx()

# Plot the Cost of Living data on the second axis
ax2.plot(df1['Country'], df1['Value_y'], color="cornflowerblue", marker="o")
ax2.set_ylabel("Household Disposable Income by Country", color="cornflowerblue", fontsize=14)
ax2.set_ylim(ymin=0)
ax.set_title('GDP vs. Household Disposable Income')

# Ensure the country labels are rotated to be readable
ax.tick_params(axis='x', labelrotation = 90)

plt.show()

# %%
# import dataset for GDP from https://data.oecd.org/gdp/gross-domestic-product-gdp.htm
gdpData2 = "datasets/GDP_growth.csv"

# read the data with colums - {'Country', 'Metric, 'Subject', 'Measure', 'Frequency', 'Year', 'Value', 'Flag'}
rawGDP_df2 = pd.read_csv(gdpData)

rawGDP_df2.head()
# Out:
#   LOCATION    Country TRANSACT                                    Transaction  \
# 0      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 1      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 2      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 3      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
# 4      AUS  Australia    B1_GE  Gross domestic product (expenditure approach)
#
#   MEASURE      Measure  TIME  Year Unit Code        Unit  PowerCode Code  \
# 0       G  Growth rate  2012  2012        PC  Percentage               0
# 1       G  Growth rate  2013  2013        PC  Percentage               0
# 2       G  Growth rate  2014  2014        PC  Percentage               0
# 3       G  Growth rate  2015  2015        PC  Percentage               0
# 4       G  Growth rate  2016  2016        PC  Percentage               0
#
# ...

# %%
df2 = rawGDP_df2.copy().sort_values(by = 'TIME', ascending = False)
df2
# Out:
#     LOCATION                        Country TRANSACT  \
# 382      ROU                        Romania    B1_GE
# 161     EU15  European Union (15 countries)    B1_GE
# 210      SVN                       Slovenia    B1_GE
# 370      MLT                          Malta    B1_GE
# 203      ITA                          Italy    B1_GE
# ..       ...                            ...      ...
# 169      KOR                          Korea    B1_GE
# 323      LTU                      Lithuania    B1_GE
# 176      EST                        Estonia    B1_GE
# 183      IDN                      Indonesia    B1_GE
# 0        AUS                      Australia    B1_GE
#
#                                        Transaction MEASURE      Measure  TIME  \
# 382  Gross domestic product (expenditure approach)       G  Growth rate  2018
# 161  Gross domestic product (expenditure approach)       G  Growth rate  2018
# 210  Gross domestic product (expenditure approach)       G  Growth rate  2018
# ...

# %%
df2= df2.drop(subset=['LOCATION'], keep='first')
df2.head()
